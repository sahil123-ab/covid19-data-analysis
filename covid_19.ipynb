# %% [markdown]
# # Data Analysis with Python using Pandas: COVID-19 Dataset
#
# Working on a real data analysis project using Python and a CSV dataset.
#
# ## Requirements / Questions
#
#  Q1. Show the total number of Confirmed, Deaths, and Recovered cases in each Region.
#
#  Q2. In which Region the maximum number of confirmed cases were recorded?
#
#  Q3. In which Region the minimum number of deaths were recorded?
#
#  Q4. How many Confirmed, Deaths, and Recovered cases were reported for Europe?
#
#  Q5.Remove all the records where confirmed cases are less than 10
#
# ---

# %%
import pandas as pd


pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)


covid_19=pd.read_csv(r"C:\Users\Rudr\Downloads\covid19_project_dataset.csv")
covid_19
# Out:
#            Date       Country         Region  Confirmed  Deaths  Recovered
# 0    2020-03-01           USA  North America      34727     565      16074
# 1    2020-03-01     Australia        Oceania      25378     663      15326
# 2    2020-03-01  South Africa         Africa        725      27        643
# 3    2020-03-02         Italy         Europe      44412     961      21071
# 4    2020-03-03         Spain         Europe      19900     315       8257
# 5    2020-03-03       Germany         Europe       6750      81       3123
# 6    2020-03-03       Germany         Europe       3287      75       2746
# 7    2020-03-03           USA  North America       8628     264       4905
# 8    2020-03-04       Germany         Europe      12711     504       8633
# 9    2020-03-04       Germany         Europe      27603    1088      15115
# 10   2020-03-04     Argentina  South America       7490     356       3942
# ...

# %%
covid_19.shape
# Out:
# (220, 6)

# %%
covid_19.count()
# Out:
# Date         220
# Country      220
# Region       220
# Confirmed    220
# Deaths       220
# Recovered    220
# dtype: int64

# %%
covid_19.isnull().sum()
# Out:
# Date         0
# Country      0
# Region       0
# Confirmed    0
# Deaths       0
# Recovered    0
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.heatmap(covid_19.isnull())
plt.show()

# %% [markdown]
# Q1. Show the number of confirmed , deaths and recovered cases in each region.

# %%
covid_19.head(3)
# Out:
#          Date       Country         Region  Confirmed  Deaths  Recovered
# 0  2020-03-01           USA  North America      34727     565      16074
# 1  2020-03-01     Australia        Oceania      25378     663      15326
# 2  2020-03-01  South Africa         Africa        725      27        643

# %%
covid_19.groupby("Region").sum()
# Out:
#                                                             Date  \
# Region
# Africa         2020-03-012020-03-052020-03-102020-03-112020-0...
# Asia           2020-03-052020-03-062020-03-092020-03-122020-0...
# Europe         2020-03-022020-03-032020-03-032020-03-032020-0...
# North America  2020-03-012020-03-032020-03-122020-03-142020-0...
# Oceania        2020-03-012020-03-182020-03-182020-03-192020-0...
# South America  2020-03-042020-03-052020-03-062020-03-112020-0...
#
#                                                          Country  Confirmed  \
# Region
# Africa         South AfricaSouth AfricaEgyptSouth AfricaEgypt...     804789
# Asia           IndiaPakistanChinaIndiaChinaPakistanIndiaIndia...    1351081
# Europe         ItalySpainGermanyGermanyGermanyGermanySpainGer...    1057758
# North America  USAUSAUSACanadaCanadaCanadaCanadaUSAUSAUSAUSAC...    1048092
# Oceania        AustraliaAustraliaAustraliaAustraliaAustraliaA...     371480
# ...

# %%
covid_19.groupby("Region").sum().head(10)
# Out:
#                                                             Date  \
# Region
# Africa         2020-03-012020-03-052020-03-102020-03-112020-0...
# Asia           2020-03-052020-03-062020-03-092020-03-122020-0...
# Europe         2020-03-022020-03-032020-03-032020-03-032020-0...
# North America  2020-03-012020-03-032020-03-122020-03-142020-0...
# Oceania        2020-03-012020-03-182020-03-182020-03-192020-0...
# South America  2020-03-042020-03-052020-03-062020-03-112020-0...
#
#                                                          Country  Confirmed  \
# Region
# Africa         South AfricaSouth AfricaEgyptSouth AfricaEgypt...     804789
# Asia           IndiaPakistanChinaIndiaChinaPakistanIndiaIndia...    1351081
# Europe         ItalySpainGermanyGermanyGermanyGermanySpainGer...    1057758
# North America  USAUSAUSACanadaCanadaCanadaCanadaUSAUSAUSAUSAC...    1048092
# Oceania        AustraliaAustraliaAustraliaAustraliaAustraliaA...     371480
# ...

# %%
covid_19.groupby("Region")["Confirmed"].sum()
# Out:
# Region
# Africa            804789
# Asia             1351081
# Europe           1057758
# North America    1048092
# Oceania           371480
# South America     725763
# Name: Confirmed, dtype: int64

# %%
covid_19.groupby("Region")["Deaths"].sum()
# Out:
# Region
# Africa           23556
# Asia             39692
# Europe           33182
# North America    32125
# Oceania          11405
# South America    20705
# Name: Deaths, dtype: int64

# %% [markdown]
# Q2. In which Region the maximum number of confirmed cases were recorded?
#
# Q3. In which Region the minimum number of deaths were recorded?
#
# Q4. How many Confirmed, Deaths, and Recovered cases were reported for Europe?

# %%
covid_19.groupby("Region")["Confirmed"].sum().sort_values(ascending=False)
# Out:
# Region
# Asia             1351081
# Europe           1057758
# North America    1048092
# Africa            804789
# South America     725763
# Oceania           371480
# Name: Confirmed, dtype: int64

# %%
covid_19.groupby("Region")["Deaths"].sum().sort_values(ascending=True).head(50)
# Out:
# Region
# Oceania          11405
# South America    20705
# Africa           23556
# North America    32125
# Europe           33182
# Asia             39692
# Name: Deaths, dtype: int64

# %%
covid_19[covid_19.Region=="Europe"]
# Out:
#            Date  Country  Region  Confirmed  Deaths  Recovered
# 3    2020-03-02    Italy  Europe      44412     961      21071
# 4    2020-03-03    Spain  Europe      19900     315       8257
# 5    2020-03-03  Germany  Europe       6750      81       3123
# 6    2020-03-03  Germany  Europe       3287      75       2746
# 8    2020-03-04  Germany  Europe      12711     504       8633
# 9    2020-03-04  Germany  Europe      27603    1088      15115
# 16   2020-03-08    Spain  Europe      37030     752      20166
# 29   2020-03-14  Germany  Europe      12898     413       9398
# 31   2020-03-14    Spain  Europe      12572     427       7831
# 32   2020-03-15    Spain  Europe        738      17        538
# 35   2020-03-15  Germany  Europe      12473     552       7884
# 44   2020-03-18    Italy  Europe      13834     271       6076
# 49   2020-03-20    Italy  Europe      28338    1410      12320
# 53   2020-03-21    Italy  Europe       2475      41       1330
# ...

# %% [markdown]
# Q5. Remove all the records where confirmed cases are less than 10

# %%
covid_19.Confirmed < 1000
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26      True
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32      True
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59      True
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
covid_19[covid_19.Confirmed < 1000]
# Out:
#           Date       Country  Region  Confirmed  Deaths  Recovered
# 2   2020-03-01  South Africa  Africa        725      27        643
# 26  2020-03-13      Pakistan    Asia        949      38        658
# 32  2020-03-15         Spain  Europe        738      17        538
# 59  2020-03-22         Egypt  Africa        437      15        310

# %%
covid_19[~(covid_19.Confirmed) < 1000]
# Out:
#            Date       Country         Region  Confirmed  Deaths  Recovered
# 0    2020-03-01           USA  North America      34727     565      16074
# 1    2020-03-01     Australia        Oceania      25378     663      15326
# 3    2020-03-02         Italy         Europe      44412     961      21071
# 4    2020-03-03         Spain         Europe      19900     315       8257
# 5    2020-03-03       Germany         Europe       6750      81       3123
# 6    2020-03-03       Germany         Europe       3287      75       2746
# 7    2020-03-03           USA  North America       8628     264       4905
# 8    2020-03-04       Germany         Europe      12711     504       8633
# 9    2020-03-04       Germany         Europe      27603    1088      15115
# 10   2020-03-04     Argentina  South America       7490     356       3942
# 11   2020-03-05         India           Asia      16481     747      14298
# ...

# %%
covid_19 = covid_19[covid_19["Confirmed"] >= 1000]

covid_19
# Out:
#            Date       Country         Region  Confirmed  Deaths  Recovered
# 0    2020-03-01           USA  North America      34727     565      16074
# 1    2020-03-01     Australia        Oceania      25378     663      15326
# 3    2020-03-02         Italy         Europe      44412     961      21071
# 4    2020-03-03         Spain         Europe      19900     315       8257
# 5    2020-03-03       Germany         Europe       6750      81       3123
# 6    2020-03-03       Germany         Europe       3287      75       2746
# 7    2020-03-03           USA  North America       8628     264       4905
# 8    2020-03-04       Germany         Europe      12711     504       8633
# 9    2020-03-04       Germany         Europe      27603    1088      15115
# 10   2020-03-04     Argentina  South America       7490     356       3942
# 11   2020-03-05         India           Asia      16481     747      14298
# ...
